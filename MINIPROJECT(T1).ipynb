# %% [markdown]
# # DATA VISUVALIZATION

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %% [markdown]
# # CAR CRASHES

# %%
car_crashes=sns.load_dataset('car_crashes')

# %%
car_crashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # BAR CHART

# %%
ABBREW=['AL','AK','AZ','AR','CA']
TOTAL=[18.8,18.1,18.6,22.4,12.0]

# %%
plt.bar(ABBREW,TOTAL,color="red",edgecolor="blue")
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # SCATTER PLOT

# %%
plt.scatter(ABBREW,TOTAL,color="red",edgecolor="blue")

# %% [markdown]
# # LINE CHART

# %%
plt.plot(ABBREW,TOTAL,linestyle="solid",color="red")

# %% [markdown]
# # PIE CHART

# %%
plt.pie(TOTAL,labels=game)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f77fede6d0>,
# ...
#  [Text(0.8710284877109944, 0.671795633802348, 'AL'),
#   Text(-0.4035783992500007, 1.023291002432254, 'AK'),
#   Text(-1.0958048639843405, -0.09597760190930493, 'AZ'),
#   Text(-0.05571418692084292, -1.0985881527559587, 'AR'),
#   Text(1.004691358175129, -0.447878638481693, 'CA')])
